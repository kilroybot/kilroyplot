# %%
from kilroyplot.plot import plt

# %%
plt.plot([0, 1], [0, 0], label="First")
plt.plot([0, 1], [0.33, 0], label="Second")
plt.plot([0, 1], [0.66, 0], label="Third")
plt.plot([0, 1], [1, 0], label="Fourth")
plt.suptitle("Suptitle")
plt.title("Title")
plt.legend()
plt.tight_layout()
